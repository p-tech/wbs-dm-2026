# %% [markdown]
# <a href="https://colab.research.google.com/github/p-tech/wbs-dm-2026/blob/main/maths/simple_maths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Create Database

# %%
import sqlite3
import pandas as pd

# Create or connect to a database file
conn = sqlite3.connect("shop.db")
cur = conn.cursor()

print("Database connected successfully.")
# Out:
# Database connected successfully.

# %% [markdown]
# Create simple Table

# %%
cur.execute("""
CREATE TABLE IF NOT EXISTS sales (
    sale_id INTEGER PRIMARY KEY AUTOINCREMENT,
    product_name TEXT,
    category TEXT,
    price REAL,
    quantity INTEGER
);
""")

conn.commit()
print("Table created.")
# Out:
# Table created.

# %% [markdown]
# Insert sample data

# %%
cur.executemany("""
INSERT INTO sales (product_name, category, price, quantity)
VALUES (?, ?, ?, ?);
""", [
    ('Laptop', 'Electronics', 800, 2),
    ('Phone', 'Electronics', 500, 3),
    ('Headphones', 'Electronics', 100, 5),
    ('Desk Chair', 'Furniture', 150, 4),
    ('Desk', 'Furniture', 300, 2),
    ('Notebook', 'Stationery', 5, 20),
    ('Pen Pack', 'Stationery', 10, 10)
])

conn.commit()
print("Data inserted.")
# Out:
# Data inserted.

# %% [markdown]
# View all data

# %%
df = pd.read_sql_query(" ", conn)
df

# %% [markdown]
# Calculate the AVG Price

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate Total Quantity Sold

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate Highest and Lowest Price

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate revenue per product

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate total revenue

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate revenue per category

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate average price per category

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Calculate count products per category

# %%
pd.read_sql_query("""

""", conn)

# %% [markdown]
# Which category has a revenue greater than 2000

# %%
pd.read_sql_query("""

""", conn)
