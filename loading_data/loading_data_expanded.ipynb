# %% [markdown]
# <a href="https://colab.research.google.com/github/p-tech/wbs-dm-2026/blob/main/loading_data/loading_data_expanded.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1: Import pandas

# %%
import pandas as pd

# Install pandas if not already installed
# !pip install pandas

# %% [markdown]
# # Working with CSV files:
# # Task 1:
# Load the csv 'loading_data_file.csv' file into a dataframe - labelled as df

# %%
df = pd.read_csv('loading_data_csv.csv')

# %% [markdown]
# Show the first 5 lines of the csv file.

# %%
df.head(5)

# %% [markdown]
# Modify the above line of code to show the first 15 lines of the dataframe.

# %% [markdown]
# Modify the above line of code to show the last 15 lines of the dataframe

# %% [markdown]
# #Task 2:
# Load the data file 'loading_data_csv_nh.csv'<br/>What do you observe about the data?

# %%
df2 = pd.read_csv('loading_data_csv_nh.csv')

# %% [markdown]
# Print the first 5 lines of the file.

# %%
df2.head(5)

# %% [markdown]
# **Question:**
# <br>What do you notice about the data compared to previous example.

# %% [markdown]
# # Task 3
# Adding headers to the file.

# %%
headers = [
    "OrderID",<ADD FILEDS>,"Country"
]

# %% [markdown]
# Reload the file and add the headers to the file.

# %%
df3 = pd.read_csv("loading_data_csv_nh.csv", header=None)
df3.columns = headers

# %% [markdown]
# Display the first 10 lines of the file.

# %%
df3.head(15)

# %% [markdown]
# Task:
# Find all orders from the UK.

# %%
uk_orders = df3[df3["Country"] == "UK"]
print (uk_orders)

# %% [markdown]
# Return all returned orders

# %%
returned_orders = <ENTER CODE>
print (returned_orders)

# %% [markdown]
# Return all orders from the UK with quantity over 2 items

# %%
uk_orders_large = <ENTER CODE>
print (uk_orders_large)

# %% [markdown]
# # Ordering Data

# %% [markdown]
# Order by date

# %%
sorted_data = df3.sort_values("OrderDate", ascending=False)
print (sorted_data)

# %% [markdown]
# How would you change the order

# %%
sorted_data = df3.sort_values(<ENTER CODE>)
print (sorted_data)

# %% [markdown]
# # Manipulating Data

# %% [markdown]
# Sales by product

# %%
quantity_by_product = (
    df3.groupby("ProductName")["Quantity"].sum()
)
print (quantity_by_product)

# %% [markdown]
# How would you find the Total Revenue

# %% [markdown]
# # Spliting the data files

# %% [markdown]
# Create three files for:<br>
# Customers<br>
# Products<br>
# Orders<br>
# <br>
# What's the first stage before splitting the data?

# %%
customers = df3[['CustomerID','CustomerName','Email']].drop_duplicates()
print (customers)

customers.to_csv('customers.csv', index=False)

# %%
<Create the additional files>
